# %% [markdown]
# 1 Based on what you have learnt in the class, do the following steps:
#
#  Create a new folder
#
#    b. Put the following files in the folder
#
#
#             Code.txt
#
#             Log.txt
#
#             Output.txt
#
# c. Stage the Code.txt and Output.txt files
#
# d. Commit them
#
# e. And finally push them to GitHub
#
# ANS :-
#
# Create folder and add file code , log and output.txt
#
# ![image.png](data:image/png;base64,...)
#
# The command which we going to use
# 1. git init – Initializes a new Git repository in your current directory.
# 2. git add . – Stages all changes (new, modified, deleted files) for the next commit.
# 3. git commit -m "message" – Saves the staged changes with a descriptive commit message.
# 4. git push – Uploads your local commits to the remote repository (e.g., GitHub).
#
# Now I will yse GIT init to create Git Repository , then I will add Code.txt and Output.txt ,
# after that I wll check the stage of that file so  i can understand what is the current sage of the file which i want in my Git Repository
# After that I will use GIt commit command finally after that i will push the file into repostory
#
# ![image.png](data:image/png;base64,...)
#
# In this image we have Initializes a new Git repository, and added Code and output.txt
# Use git status command to check there Stage
#
# ![image.png](data:image/png;base64,...)
#
# Now I will push the file into my repository
#
#  ![image.png](data:image/png;base64,...)
#
#  Now the file output and code.txt has been added to the repostory

# %% [markdown]
# Q2. Please share the commands for the above point
#
#   Tasks to Be Performed:
#
# 1. Create a Git working directory with feature1.txt and feature2.txt in the master branch
#
# 2. Create 3 branches develop, feature1 and feature2
#
# 3. In develop branch create develop.txt, do not stage or commit it
#
# 4. Stash this file and check out to feature1 branch
#
# 5. Create new.txt file in feature1 branch, stage and commit this file
#
# 6. Checkout to develop, unstash this file and commit
#
# 7. Please submit all the Git commands used to do the above step>
#
# ANS - >
# Task 1: Create a Git working directory with feature1.txt and feature2.txt in the master branch
#
# 1 mkdir git-assignment
#
# 2 cd git-assignment
#
# 3 git init
#
# 4 touch feature1.txt feature2.txt
#
# 5 git add feature1.txt feature2.txt
#
# 6 git commit -m "Add feature1.txt and feature2.txt to master"
#
#
# SS about this code
#
# ![image.png](data:image/png;base64,...)
#
# Task 2: Create 3 branches — develop, feature1, and feature2
#
# git branch develop
#
# git branch feature1
#
# git branch feature2
#
# ![image.png](data:image/png;base64,...)
#
#
# Task 3: In develop branch, create develop.txt, do not stage or commit it
#
# git checkout develop
# touch develop.txt
#
# ![image.png](data:image/png;base64,...)
#
#
# Task 4: Stash this file and checkout to feature1 branch
#
# git stash
# git checkout feature1
#
# ![image.png](data:image/png;base64,...)
#
# Task 5: In feature1 branch, create new.txt, stage and commit it
#
# touch new.txt
#
# git add new.txt
#
# git commit -m "Add new.txt in feature1 branch"
#
# ![image.png](data:image/png;base64,...)
#
#
#  Task 6: Checkout to develop, unstash the file and commit
#
# git checkout develop
#
# git stash pop
#
# git add develop.txt
#
# git commit -m "Add develop.txt after unstashing"
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Question no 3
#
# Y Tasks to Be Performed:
#
#
# 1. Create a Git working directory, with the following branches:
#
#
#                Develop
#
#                F1
#
#                f2
#
#
# 2. In the master branch, commit main.txt file
#
# 3. Put develop.txt in develop branch, f1.txt and f2.txt in f1 and f2 respectively
#
# 4. Push all these branches to GitHub
#
# 5. On local delete f2 branch
#
# 6. Delete the same branch on GitHub as well
#
# ANS -->>
#
# Task 1: Create Git working directory and branches
#
# git checkout -b develop
#
# git checkout -b f1
#
# git checkout -b f2
#
# git checkout -b master
#
# ![image.png](data:image/png;base64,...)
#
#
# Task 2: Commit main.txt in master
#
# ![image.png](data:image/png;base64,...)
#
# Task 3: Add files to each branch
#
#
# ![image.png](data:image/png;base64,...)
#
#
# Task 4: Push all branches to GitHub
#
# git remote add origin https://github.com/aryansaroj77/GIT_ASSIGMENT.git
#
# git push -u origin master
# git push -u origin develop
# git push -u origin f1
# git push -u origin f2
#
# ![image.png](data:image/png;base64,...)
#
# i used git pull origin master --rebase
# becasue master branch was already uploded so i need use --rebase to uploded master on git hub
#
#
# Task 5: Delete f2 branch locally
#
# ![image.png](data:image/png;base64,...)
#
#
# Task 6: Delete f2 branch from GitHub
#
#
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Question no 4
#
# 1. Put master.txt on master branch, stage and commit
#
# 2. Create 3 branches: public 1, public 2 and private
#
# 3. Put public1.txt on public 1 branch, stage and commit
#
# 4. Merge public 1 on master branch
#
# 5. Merge public 2 on master branch
#
# 6. Edit master.txt on private branch, stage and commit
#
# 7. Now update branch public 1 and public 2 with new master code in private
#
# 8. Also update new master code on master
#
# 9. Finally update all the code on the private branch
#
# ANS -->>>
#
#
# TASK 1 .  add master.txt, in master branch , stage and commit
#
# git init
#
# touch master.txt
#
# git add master.txt
#
# git commit -m "Add master.txt in master branch"
#
# ![image.png](data:image/png;base64,...)
#
#
#  2. Create 3 branches: public1, public2, and private
#
#  git branch public1
#
#  git branch public2
#
#  git branch private
#
#
#  ![image.png](data:image/png;base64,...)
#
#
#  3. Add public1.txt in public1 branch, stage and commit
#
#  git checkout public1
#
#  touch public1.txt
#
#  git add public1.txt
#
#  git commit -m "Add public1.txt in public1 branch"
#
# ![image.png](data:image/png;base64,...)
#
#
#  4. Merge public1 into master
#
#  git checkout master
#
#  git merge public1 -m "Merge public1 into master"
#
#
#
#   ![image.png](data:image/png;base64,...)
#
#
#
#
#   5. Merge public2 into master
#
#
#   git merge public2 -m "Merge public2 into master"
#
# ![image.png](data:image/png;base64,...)
#
#
#  6. Edit master.txt in private branch, stage and commit
#
#   git checkout private
#
#    echo "Updated by private branch" >> master.txt
#
#   git add master.txt
#
#    git commit -m "Edit master.txt in private branch"
#
#
# ![image.png](data:image/png;base64,...)
#
#
# # 7. Update public1 and public2 with new master code from private
#
# # Merge private into public1
#
# git checkout public1
#
# git merge private -m "Merge private into public1"
#
#
# # Merge private into public2
#
# git checkout public2
#
# git merge private -m "Merge private into public2"
#
# ![image.png](data:image/png;base64,...)
#
# 8. Update master with latest code from private
#
#
# git checkout master
# git merge private -m "Merge private into master"
#
#
#
# ![image.png](data:image/png;base64,...)
#
#
#  9. Finally, update all code on the private branch
#
#
#  git checkout private
# git merge master -m "Final merge from master into private"
#
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 5 Tasks to Be Performed:
#
# 1. Create a Git Flow workflow architecture on Git
#
# 2. Create all the required branches
#
# 3. starting from e feature branch, push the branch to the master, following the architecture
#
# 4. Push an urgent.txt on master using hotfix
#
# ANS->>>>>
#
#  Git Flow Overview
#
# Git Flow typically uses the following branches:
#
# master: production-ready code
#
# develop: active development
#
# feature/*: new features
#
# release/*: release preparation
#
# hotfix/*: quick patches on master
#
# bugfix/*: bug fixes (optional)
#
# 1. Create Git Flow architecture in a new repo
#
# mkdir  GIT-Q5
#
# cd GIT-Q5
#
# git init
#
# ![image.png](data:image/png;base64,...)
#
# 2. Create required branches
#
# # Start from master
#
# touch master.txt
#
# git add master.txt
#
# git commit -m "Initial commit on master"
#
#
# # Create develop branch
#
# git checkout -b develop
#
#
# # Create a feature branch
#
# git checkout -b feature/login
#
#
#
# ![image.png](data:image/png;base64,...)
#
#
# 3. Feature development → Merge to develop → Merge to master via release
#
# # Switch to feature branch and add feature
#
# git checkout feature/login
#
# touch login.txt
#
# git add login.txt
#
# git commit -m "Add login feature"
#
#
# # Merge feature → develop
#
# git checkout develop
#
# git merge feature/login -m "Merge login feature into develop"
#
#
# # Prepare release → merge release to master
#
# git checkout release/v1.0
#
# git merge develop -m "Merge develop into release v1.0"
#
# git checkout master
#
# git merge release/v1.0 -m "Release v1.0 to production (master)"
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)
#
#
#  4. Push urgent.txt to master using a hotfix
#
#  # Create hotfix branch from master
#
# git checkout master
#
# git checkout -b hotfix/urgent-issue
#
#
# # Add urgent fix
#
# touch urgent.txt
#
# git add urgent.txt
#
# git commit -m "Hotfix: Add urgent.txt to master"
#
#
# # Merge hotfix to master and develop
#
# git checkout master
#
# git merge hotfix/urgent-issue -m "Merge hotfix into master"
#
#
# git checkout develop
#
# git merge hotfix/urgent-issue -m "Merge hotfix into develo
#
#
# ![image.png](data:image/png;base64,...)
#
#
# Final Branch Structure
#
# ![image.png](data:image/png;base64,...)
